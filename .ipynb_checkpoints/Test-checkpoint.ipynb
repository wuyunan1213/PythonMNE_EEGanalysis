# %%
import warnings
warnings.simplefilter("ignore", DeprecationWarning)
import mne
import numpy as np
import scipy, time
import scipy.io
import scipy.stats
import matplotlib
import matplotlib.pyplot as plt

import sys



tmp_rootdir = '/Users/charleswu/Desktop/MNE/'
raw_dir = tmp_rootdir + "raw_data/"
filtered_dir = tmp_rootdir + "filtered_raw_data/"
ica_dir = tmp_rootdir + "ica_raw_data/" 
word_epoch_dir = tmp_rootdir + "word_epoch_raw_data/"
evoked_dir = tmp_rootdir + "evoked/"

Mastoids = ['M1','M2']
EOG_list = ['HEOG', 'VEOG']
n_eeg_channels = 32

trigger_list = ['STI 014']
l_freq = 0.1
h_freq = 110.0
notch_freq = [60.0,120.0]
fname_suffix = "filter_%d_%dHz_notch_raw" %(l_freq, h_freq)
alpha = 15
event_dir = tmp_rootdir + "event_files/"
event_id = {'English': 1, 
            'S1/MU2/CON': 120,
            'S1/MU2/TAR': 121,
            'S1/ZHUO2/CON': 140, 
            'S1/ZHUO2/TAR': 141, 
            'S3/MU7/CON': 320,
            'S3/MU7/TAR': 321,
            'S3/ZHUO7/CON': 340, 
            'S3/ZHUO7/TAR': 341,
            'S5/MU5/CON': 520,
            'S5/MU5/TAR': 521, 
            'S5/ZHUO5/CON':540,
            'S5/ZHUO5/TAR':541,
            'S6/MU4/CON':620,
            'S6/MU4/TAR':621,
            'S6/ZHUO4/CON':640,
            'S6/ZHUO4/TAR':641}

# for cond in event_id:
#     evoked = epochs[cond].average()
#     evoked.plot_joint(title = cond)

subj_list = ["S01", "S02"]
session_list = ['PRE','POST']
n_subj = len(subj_list) 
n_sesh = len(session_list)
words = ['TAR','CON']
warnings.simplefilter("ignore", DeprecationWarning)
##read the events from the event files instead of the stim channels in the data.
evoked_dict = dict()

for word in words:
    for j in range(n_sesh):
        sesh = session_list[j]
        for i in range(n_subj):
            subj = subj_list[i]
            fname = word_epoch_dir + "%s_%s_%s_word-epo.fif" %(subj, sesh, fname_suffix)
            epochs = mne.read_epochs(fname, preload = False)
            if i == 0:
                evoked = [epochs[word].average()]
            else:
                evoked.append(epochs[word].average())
        word_sesh = mne.grand_average(evoked).crop(-0.2,0.5)
        write_name = evoked_dir + "%s_%s_%s-ave.fif" %(word, sesh, fname_suffix)
        evoked_dict["%s/%s" %(word, sesh)] = word_sesh


colors = dict(TAR="Crimson", CON="CornFlowerBlue")
linestyles = dict(PRE='--', POST='-')
pick_FZ = epochs['S6/ZHUO4/TAR'].ch_names.index('FZ')
pick_CZ = epochs['S6/ZHUO4/TAR'].ch_names.index('CZ')
pick_PZ = epochs['S6/ZHUO4/TAR'].ch_names.index('PZ')

fig, ax = plt.subplots()
mne.viz.plot_compare_evokeds(evoked_dict, picks=pick_CZ, colors=colors, 
                             linestyles = linestyles, 
                             truncate_xaxis=False, axes = ax)


from mne.channels.layout import find_layout
layout = find_layout(word_sesh.info)
pos = layout.pos.copy()

f = plt.figure()
f.set_size_inches((10,10))

ylims = (-1, 2)
ymax = np.min(np.abs(np.array(ylims)))

conditions = ["CON/PRE", "TAR/PRE", "CON/POST", "TAR/POST"]

colors = dict(TAR="Crimson", CON="CornFlowerBlue")
linestyles = dict(PRE='--', POST='-')
for pick, (pos_, ch_name) in enumerate(zip(pos, epochs.ch_names)):
    ax = plt.axes(pos_)
    mne.viz.plot_compare_evokeds(evoked_dict, picks = pick, 
                                 axes = ax, 
                                 colors=colors, 
                             linestyles = linestyles,
                                 show_legend = False,
                                 show_sensors = False,title = '')
    ax.set_ylabel('')
    ax.set_xlabel('')
    ax.set_yticks((-ymax, ymax))
    ax.spines["left"].set_bounds(-ymax, ymax)
    ax.set_ylim(ylims)
    ax.set_yticklabels('')
    ax.text(-.1, 1, ch_name, transform=ax.transAxes)
    
ax_l = plt.axes([5, 5] + list(pos[2, 5:]))
mne.viz.plot_compare_evokeds(evoked_dict, title='', 
                     picks=0, axes=ax_l, ci=None,
                     show_legend = False,
                     show_sensors = False,
                             show=False)

ax_l.set_yticks((-ymax, ymax))
ax_l.spines["left"].set_bounds(-ymax, ymax)
ax_l.set_ylim(ylims)
ax_l.lines.clear()
ax_l.patches.clear()
# Out:
# Reading /Users/charleswu/Desktop/MNE/word_epoch_raw_data/S01_PRE_filter_0_110Hz_notch_raw_word-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    -600.00 ...     600.00 ms
#         0 CTF compensation matrices available
# 2966 matching events found
# 2966 matching events found
# 0 projection items activated
# Reading /Users/charleswu/Desktop/MNE/word_epoch_raw_data/S02_PRE_filter_0_110Hz_notch_raw_word-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    -600.00 ...     600.00 ms
#         0 CTF compensation matrices available
# 3396 matching events found
# 3396 matching events found
# 0 projection items activated
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-505b782e61c2> in <module>()
#      72                 evoked = [epochs[word].average()]
#      73             else:
# ---> 74                 evoked.append(epochs[word].average())
#      75         word_sesh = mne.grand_average(evoked).crop(-0.2,0.5)
#      76         write_name = evoked_dir + "%s_%s_%s-ave.fif" %(word, sesh, fname_suffix)
#
# /anaconda2/lib/python2.7/site-packages/mne/epochs.pyc in average(self, picks)
#     750         channels are selected when picks is None.
#     751         """
# --> 752         return self._compute_mean_or_stderr(picks, 'ave')
#     753
#     754     def standard_error(self, picks=None):
#
# /anaconda2/lib/python2.7/site-packages/mne/epochs.pyc in _compute_mean_or_stderr(self, picks, mode)
#     794             data = np.zeros((n_channels, n_times))
#     795             n_events = 0
# --> 796             for e in self:
#     797                 data += e
#     798                 n_events += 1
#
# /anaconda2/lib/python2.7/site-packages/mne/epochs.pyc in __iter__(self)
#    1239         self._current = 0
#    1240         while True:
# -> 1241             x = self.next()
#    1242             if x is None:
#    1243                 return
#
# /anaconda2/lib/python2.7/site-packages/mne/epochs.pyc in next(self, return_event_id)
#    1270                     return  # signal the end properly
#    1271                 epoch_noproj = self._get_epoch_from_raw(self._current)
# -> 1272                 epoch_noproj = self._detrend_offset_decim(epoch_noproj)
#    1273                 epoch = self._project_epoch(epoch_noproj)
#    1274                 self._current += 1
#
# /anaconda2/lib/python2.7/site-packages/mne/epochs.pyc in _detrend_offset_decim(self, epoch, verbose)
#
# /anaconda2/lib/python2.7/site-packages/mne/utils.pyc in verbose(function, *args, **kwargs)
#     726         with use_log_level(verbose_level):
#     727             return function(*args, **kwargs)
# --> 728     return function(*args, **kwargs)
#     729
#     730
#
# /anaconda2/lib/python2.7/site-packages/mne/epochs.pyc in _detrend_offset_decim(self, epoch, verbose)
#     619                            ref_meg=True, eog=True, ecg=True, seeg=True,
#     620                            emg=True, bio=True, ecog=True, fnirs=True,
# --> 621                            exclude=[])
#     622         epoch[picks] = rescale(epoch[picks], self._raw_times, self.baseline,
#     623                                copy=False, verbose=False)
#
# /anaconda2/lib/python2.7/site-packages/mne/io/pick.pyc in pick_types(info, meg, eeg, stim, eog, ecg, emg, ref_meg, misc, resp, chpi, exci, ias, syst, seeg, dipole, gof, bio, ecog, fnirs, include, exclude, selection)
#     363         sel = np.array([], int)
#     364     else:
# --> 365         sel = pick_channels(info['ch_names'], myinclude, exclude)
#     366
#     367     return sel
#
# /anaconda2/lib/python2.7/site-packages/mne/io/pick.pyc in pick_channels(ch_names, include, exclude)
#     122     sel = []
#     123     for k, name in enumerate(ch_names):
# --> 124         if (len(include) == 0 or name in include) and name not in exclude:
#     125             sel.append(k)
#     126     return np.array(sel, int)
#
# KeyboardInterrupt:

# %%
epochs['TAR']
# Out:
# <EpochsFIF  |  n_events : 1598 (all good), tmin : -0.6 (s), tmax : 0.6 (s), baseline : (-0.20000000298023224, 0.0), ~80 kB, data not loaded,
#  u'S1/MU2/TAR': 199, u'S1/ZHUO2/TAR': 200, u'S3/MU7/CON': 200, u'S3/MU7/TAR': 200, u'S3/ZHUO7/TAR': 200, u'S5/MU5/TAR': 200, u'S5/ZHUO5/TAR': 199, u'S6/MU4/TAR': 200, u'S6/ZHUO4/TAR': 200>

# %%
epochs.plot_image(5,cmap='interactive', sigma=1)
# Out:
# Loading data for 3196 events and 1201 original time points ...
